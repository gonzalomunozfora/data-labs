# %% [markdown]
# PANDAS PROJECT

# %%
import pandas as pd

# %%
# Para que se lea correctamente el .csv, hay que definir el encoding:

sharks_df = pd.read_csv('./GSAF5.csv', encoding = 'ISO-8859-1')

#..input/GSAF5.csv para leer el csv cuado no esta en la misma carpeta

# %%
sharks_df.head(15) #Para una primera visualización del df
# Out:
#      Case Number       Date  Year        Type        Country  \
# 0   2016.09.18.c  18-Sep-16  2016  Unprovoked            USA
# 1   2016.09.18.b  18-Sep-16  2016  Unprovoked            USA
# 2   2016.09.18.a  18-Sep-16  2016  Unprovoked            USA
# 3     2016.09.17  17-Sep-16  2016  Unprovoked      AUSTRALIA
# 4     2016.09.15  16-Sep-16  2016  Unprovoked      AUSTRALIA
# 5   2016.09.15.R  15-Sep-16  2016        Boat      AUSTRALIA
# 6     2016.09.11  11-Sep-16  2016  Unprovoked            USA
# 7     2016.09.07  07-Sep-16  2016  Unprovoked            USA
# 8     2016.09.06  06-Sep-16  2016  Unprovoked  NEW CALEDONIA
# 9   2016.09.05.b  05-Sep-16  2016  Unprovoked            USA
# 10  2016.09.05.a  05-Sep-16  2016  Unprovoked      AUSTRALIA
# 11    2016.09.04  04-Sep-16  2016  Unprovoked            USA
# 12    2016.09.01  01-Sep-16  2016  Unprovoked            USA
# 13  2016.08.29.b  29-Aug-16  2016  Unprovoked            USA
# ...

# %%
# Analizamos el df con df.info() y comprobamos que tiene 24 columnas y 5592 registros.

#Es significativo que solo 8 de las 24 columnas tengan los 5592 registros cumplimentados (sin nulos)
# Y que la mayoria son tipo objeto, cuando debería haber datatime, más numéricos, algún booleano...
sharks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5992 entries, 0 to 5991
# Data columns (total 24 columns):
# Case Number               5992 non-null object
# Date                      5992 non-null object
# Year                      5992 non-null int64
# Type                      5992 non-null object
# Country                   5949 non-null object
# Area                      5590 non-null object
# Location                  5496 non-null object
# Activity                  5465 non-null object
# Name                      5792 non-null object
# Sex                       5425 non-null object
# Age                       3311 non-null object
# Injury                    5965 non-null object
# Fatal (Y/N)               5973 non-null object
# Time                      2779 non-null object
# Species                   3058 non-null object
# Investigator or Source    5977 non-null object
# pdf                       5992 non-null object
# href formula              5991 non-null object
# ...

# %%
sharks_df.isnull().sum()

#Vemos los nulos que hay para cada columna, para eliminarlas si hay muchos.
# Out:
# Case Number                  0
# Date                         0
# Year                         0
# Type                         0
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# pdf                          0
# href formula                 1
# href                         3
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64

# %%
sharks_df.columns

#Comprobamos los nombres de las columnas para poder tratarlas.
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
sharks_df.columns.str.strip()
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
sharks_df.drop(['Age','Time','Species','Unnamed: 22',"Unnamed: 23"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-efb654defd78> in <module>
# ----> 1 sharks_df.drop(['Age','Time','Species','Unnamed: 22',"Unnamed: 23"])
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
sharks_df.drop(['Unnamed: 22','Unnamed: 23'], axis=1,inplace=True)

sharks_df
# Eliminamos las 2 últimas columnas, ya que no tienen información relevante, son todo nulos menos 1 y 2 registros.

# %%
sharks_df.Injury().values_count()

# %%
shark_df_rename = shark_df.rename(columns={'Fatal (Y/N)': 'Fatal'}, inplace=False)
shark_df_rename.columns.tr

# %%
shark_df_rename.Fatal.value_counts()

#para limpiar esta columna se podria pasar primero los datos que sabemos que son ciertos a TRUE y luego crear una funcion que transforme lo que no es True en Falso

# %%
sharks_df.columns.str.strip()

# %%
shark_df['Species '].value_counts()

# %%
shark_df.max()

# %%
1) El date tendria que ser nun tipo datetime

2) En los data set cuando hay varios tipos en una misma columna, al final muestra el tipo que engloba a todos. Por ejemplo si en una columna hay enteros y 1 float, te marca
como tipo float, ya que el float incluye a los enteros, pero los enteros no incluyen a los decimales.

Si en una columna hay enteros, float y str, te muestra como tipo object, ya que engloba a todos


3) quitar los espacios de las columnas, con strip

4) ver los nulos number_of_nulls= shark_df.isnull.sum()

5)

# %%
import matplotlib.pyplot as plot

sharks_df['Year'].plot.hist()
